# %%
import tensorflow as tf
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create features
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

plt.scatter(X,y)

# %%
y == X + 10
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# ## Input and output shapes

# %%
# Create a demo tensor for our housing price prediction problem
house_info = tf.constant(['bedroom','bathroom','garage'])
house_price = tf.constant([939700])
house_info,house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %%
X[0],y[0]
# Out:
# (-7.0, 3.0)

# %%
input_shape = X[0].shape
output_shape = y[0].shape
input_shape,output_shape
# Out:
# ((), ())

# %%
X[0].ndim
# Out:
# 0

# %%
X[0],y[0]
# Out:
# (-7.0, 3.0)

# %%
# Turn our NumPy arrays into tensors with dtype float32
X = tf.cast(tf.constant(X),dtype=tf.float32)
y = tf.cast(tf.constant(y),dtype=tf.float32)
X,y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
input_shape = X[0].shape
output_shape = y[0].shape
input_shape,output_shape
# Out:
# (TensorShape([]), TensorShape([]))

# %%
plt.scatter(X,y)

# %% [markdown]
# ## Steps in modelling with TensorFlow
#
# 1. **Creating a model** - define the input and output layers, as well as the hidden layers of a deep learning model.
# 2. **Compiling a model** - define the loss funtion (in other words, the function which tells our model how wrong it is) and the optimizer (tells our model how to improve the patterns its learning) and evaluation metrics (what we can use to interpret the performance of our model).
# 3. Fitting a model - letting the model try to find patterns between X & y (features and labels).

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create a model using the Sequential API
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1,input_shape=(1,))
])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.SGD(), # sgd is short for stochasitc gradient descent
              metrics=["mae"])

# 3. Fit the model
model.fit(X, y, epochs=5)
# Out:
# Epoch 1/5
# /Users/fahimp/Desktop/Python_Frameworks/Deeplearning-with_tensorflow/tf-env/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 13.6767 - mae: 13.6767
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 13.5442 - mae: 13.5442
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 13.4117 - mae: 13.4117
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 13.2792 - mae: 13.2792
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 13.1467 - mae: 13.1467

# %%
# Check out X and y
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
# Try and make a prediction using our model
y_pred = model.predict(tf.constant([17.0]))
y_pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# array([[2.166935]], dtype=float32)

# %%
y_pred+11
# Out:
# array([[13.166935]], dtype=float32)

# %% [markdown]
# ## Improving our model
#
# We can improve our model, by altering the steps we took to create a model.
#
# 1. **Creating a model** - here we might add more layers, increase the number of hidden units (all called neurons) within each of the hideen layers, change the activation function of each layer.
# 2. **Compiling a model** - here we might change the optimization function or perhaps the **learning rate** of the optimization function.
# 3. **Fitting a model** - here we might fit a model for more **epochs** (leave it training for longer) or on more data (give the model more examples to learn from).

# %%
# Let's rebuild our model

# 1. Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1,input_shape=(1,))
])
# 2. Compile the model
model.compile(loss=tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics = ['mae'])


# 3. Fit the model (this time we'll train for longer)
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# /Users/fahimp/Desktop/Python_Frameworks/Deeplearning-with_tensorflow/tf-env/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 10.3941 - mae: 10.3941
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 10.2616 - mae: 10.2616
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 10.1291 - mae: 10.1291
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.9966 - mae: 9.9966
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.8641 - mae: 9.8641
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.7316 - mae: 9.7316
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.5991 - mae: 9.5991
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.4666 - mae: 9.4666
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.3341 - mae: 9.3341
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.2016 - mae: 9.2016
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.0691 - mae: 9.0691
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9366 - mae: 8.9366
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.8041 - mae: 8.8041
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.6716 - mae: 8.6716
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.5391 - mae: 8.5391
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.4066 - mae: 8.4066
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.2741 - mae: 8.2741
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.1416 - mae: 8.1416
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.0091 - mae: 8.0091
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.8766 - mae: 7.8766
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.7441 - mae: 7.7441
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.6117 - mae: 7.6117
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.4791 - mae: 7.4791
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.3467 - mae: 7.3467
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.3200 - mae: 7.3200
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.3144 - mae: 7.3144
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.3088 - mae: 7.3088
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.3031 - mae: 7.3031
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2975 - mae: 7.2975
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.2919 - mae: 7.2919
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2863 - mae: 7.2863
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2806 - mae: 7.2806
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2750 - mae: 7.2750
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.2694 - mae: 7.2694
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.2638 - mae: 7.2638
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2581 - mae: 7.2581
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2525 - mae: 7.2525
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.2469 - mae: 7.2469
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2413 - mae: 7.2413
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2356 - mae: 7.2356
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2300 - mae: 7.2300
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2244 - mae: 7.2244
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.2188 - mae: 7.2188
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.2131 - mae: 7.2131
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2075 - mae: 7.2075
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2019 - mae: 7.2019
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1963 - mae: 7.1963
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1906 - mae: 7.1906
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1850 - mae: 7.1850
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1794 - mae: 7.1794
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.1737 - mae: 7.1737
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1681 - mae: 7.1681
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1625 - mae: 7.1625
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.1569 - mae: 7.1569
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1512 - mae: 7.1512
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.1456 - mae: 7.1456
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.1400 - mae: 7.1400
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1344 - mae: 7.1344
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1288 - mae: 7.1288
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1231 - mae: 7.1231
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.1175 - mae: 7.1175
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1119 - mae: 7.1119
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.1063 - mae: 7.1063
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.1006 - mae: 7.1006
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0950 - mae: 7.0950
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0894 - mae: 7.0894
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0838 - mae: 7.0838
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0781 - mae: 7.0781
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0725 - mae: 7.0725
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0669 - mae: 7.0669
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.0613 - mae: 7.0613
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0556 - mae: 7.0556
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0500 - mae: 7.0500
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0444 - mae: 7.0444
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.0388 - mae: 7.0388
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.0331 - mae: 7.0331
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0275 - mae: 7.0275
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0219 - mae: 7.0219
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.0163 - mae: 7.0163
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0106 - mae: 7.0106
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0050 - mae: 7.0050
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.9994 - mae: 6.9994
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.9938 - mae: 6.9938
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.9881 - mae: 6.9881
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.9825 - mae: 6.9825
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.9769 - mae: 6.9769
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.9713 - mae: 6.9713
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.9656 - mae: 6.9656
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.9600 - mae: 6.9600
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.9544 - mae: 6.9544
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.9488 - mae: 6.9488
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.9431 - mae: 6.9431
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.9375 - mae: 6.9375
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.9319 - mae: 6.9319
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.9263 - mae: 6.9263
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.9206 - mae: 6.9206
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.9150 - mae: 6.9150
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 6.9094 - mae: 6.9094
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.9038 - mae: 6.9038
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.8981 - mae: 6.8981

# %%
# Remind ourselves of the data
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
# Let's see if our model's prediction has improved...
model.predict(tf.constant([17.0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# array([[30.175556]], dtype=float32)

# %%
# Let's see if we can make another to improve our model

# 1. Create the model (this time with an extra hidden layer with 100 hidden units)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(50,input_shape=(1,),activation=None),
    tf.keras.layers.Dense(1,input_shape=(1,))
])
# 2. Compile the model
model.compile(loss='mae',
              optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01),
              metrics = ['mae'])
# 3. Fit the model
model.fit(X,y,epochs=100)
# Out:
# /Users/fahimp/Desktop/Python_Frameworks/Deeplearning-with_tensorflow/tf-env/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 12.9620 - mae: 12.9620
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12.2920 - mae: 12.2920
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 11.6151 - mae: 11.6151
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 10.9287 - mae: 10.9287
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 10.2300 - mae: 10.2300
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.5163 - mae: 9.5163
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.7851 - mae: 8.7851
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.0343 - mae: 8.0343
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.2616 - mae: 7.2616
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.7599 - mae: 6.7599
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.9268 - mae: 6.9268
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.2093 - mae: 7.2093
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.4367 - mae: 7.4367
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.5169 - mae: 7.5169
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 7.3948 - mae: 7.3948
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.1228 - mae: 7.1228
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.8521 - mae: 6.8521
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.5862 - mae: 6.5862
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.3048 - mae: 6.3048
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.0943 - mae: 6.0943
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.0471 - mae: 6.0471
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.0684 - mae: 6.0684
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.1344 - mae: 6.1344
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.0949 - mae: 6.0949
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.9634 - mae: 5.9634
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.7497 - mae: 5.7497
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.5721 - mae: 5.5721
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.4645 - mae: 5.4645
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.3539 - mae: 5.3539
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.3611 - mae: 5.3611
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.3397 - mae: 5.3397
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.2740 - mae: 5.2740
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.1678 - mae: 5.1678
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0244 - mae: 5.0244
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.8473 - mae: 4.8473
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6471 - mae: 4.6471
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.5496 - mae: 4.5496
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.4445 - mae: 4.4445
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3316 - mae: 4.3316
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2110 - mae: 4.2110
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.1370 - mae: 4.1370
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.9411 - mae: 3.9411
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.7703 - mae: 3.7703
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.5984 - mae: 3.5984
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.5171 - mae: 3.5171
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.4104 - mae: 3.4104
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.2491 - mae: 3.2491
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.0362 - mae: 3.0362
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.7744 - mae: 2.7744
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.5714 - mae: 2.5714
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.4622 - mae: 2.4622
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.2874 - mae: 2.2874
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.9627 - mae: 1.9627
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.7251 - mae: 1.7251
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5443 - mae: 1.5443
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3305 - mae: 1.3305
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0487 - mae: 1.0487
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.7414 - mae: 0.7414
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5945 - mae: 0.5945
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2723 - mae: 0.2723
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2268 - mae: 0.2268
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4607 - mae: 0.4607
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4883 - mae: 0.4883
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.7109 - mae: 0.7109
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.7189 - mae: 0.7189
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6902 - mae: 0.6902
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7748 - mae: 0.7748
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6523 - mae: 0.6523
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6441 - mae: 0.6441
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5833 - mae: 0.5833
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3288 - mae: 0.3288
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3428 - mae: 0.3428
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3426 - mae: 0.3426
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1315 - mae: 0.1315
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4430 - mae: 0.4430
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5798 - mae: 0.5798
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5353 - mae: 0.5353
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3306 - mae: 0.3306
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5042 - mae: 0.5042
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5896 - mae: 0.5896
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3571 - mae: 0.3571
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1751 - mae: 0.1751
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3295 - mae: 0.3295
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1750 - mae: 0.1750
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3206 - mae: 0.3206
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4367 - mae: 0.4367
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3032 - mae: 0.3032
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1268 - mae: 0.1268
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1766 - mae: 0.1766
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0493 - mae: 0.0493
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0905 - mae: 0.0905
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0717 - mae: 0.0717
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0960 - mae: 0.0960
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - mae: 0.0030
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2193 - mae: 0.2193
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1494 - mae: 0.1494
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2381 - mae: 0.2381
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2839 - mae: 0.2839
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1282 - mae: 0.1282
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2729 - mae: 0.2729

# %%
# Let's remind ourselves of the data
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
# Let's try to make a prediction
model.predict(tf.constant([17.0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# array([[26.196358]], dtype=float32)

# %% [markdown]
# ## Evaluting a model
#
# In practice, a typical workflow you'll go through when building neural networks is:
#
# ```
# Build a model  -> fit it -> evaluate it -> tweak a model -> fit it -> evaluate it -> tweak a model -> fit it -> evaluate it...
# ```

# %% [markdown]
# When it comes to evaluation... there are 3 words you should memorize:
#
# > "Visualize, visualize, visualize"
#
# It's a good idea to visualize:
# * The data - what data are we working with? What does it look like?
# * The model itself - what does our model look like?
# * The training of a model - how does a model perform while it learns?
# * The predictions of the model - how do the predictions of a model line up against the ground truth (the original labels)?

# %%
# Make a bigger dataset
X = tf.range(-100, 100, 4)
X
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
# Make labels for the dataset
y = X + 10
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
# Visualize the data
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %% [markdown]
# ### The 3 sets...
#
# * **Training set** - the model learns from this data, which is typically 70-80% of the total data you have available.
# * **Validation set** - the model gets tuned on this data, which is typically 10-15% of the data available.
# * **Test set** - the model gets evaluated on this data to test what is has learned, this set is typically 10-15% of the total data available.

# %%
# Check the length of how many samples we have
len(X)
# Out:
# 50

# %%
# Split the data into train and test sets
X_train = X[:40] # first 40 are training samples (80% of the data) 
y_train = y[:40]

X_test = X[40:] # last 10 are testing samples (20% of the data)
y_test = y[40:]

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (40, 10, 40, 10)

# %% [markdown]
# ### Visualizing the data
#
# Now we've got our data in training and test sets... let's visualize it again!

# %%
plt.figure(figsize=(10, 7))
# Plot training data in blue
plt.scatter(X_train, y_train, c="b", label="Training data") # our model will learn on this
# Plot test data in green
plt.scatter(X_test, y_test, c="g", label="Testing data") # want our model to be able to predict this (given X, what's y?)
# Show a legend
plt.legend();

# %%
# Let's have a look at how to build a neural network for our data

# 1. Create a model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1,input_shape=(1,))
])

# 2. Compile the model
model.compile(loss = tf.keras.losses.mae,
              optimizer = tf.optimizers.SGD(),
              metrics = ['mae'])

# # 3. Fit the model
model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# /Users/fahimp/Desktop/Python_Frameworks/Deeplearning-with_tensorflow/tf-env/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 11.5839 - mae: 11.5839
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.1260 - mae: 10.1260
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 19.9710 - mae: 19.9710
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.6615 - mae: 10.6615
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.3310 - mae: 10.3310
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 18.3307 - mae: 18.3307
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.9916 - mae: 12.9916
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.6506 - mae: 13.6506
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.3118 - mae: 9.3118
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 11.9648 - mae: 11.9648
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.4009 - mae: 12.4009
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.2570 - mae: 9.2570
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 11.0084 - mae: 11.0084
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 11.5593 - mae: 11.5593
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 10.9823 - mae: 10.9823
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.5666 - mae: 9.5666
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 11.5218 - mae: 11.5218
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.7647 - mae: 13.7647
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.0770 - mae: 12.0770
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 10.7331 - mae: 10.7331
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.2217 - mae: 15.2217
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.9562 - mae: 7.9562
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.4239 - mae: 8.4239
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.2469 - mae: 12.2469
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.5077 - mae: 10.5077
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.3555 - mae: 7.3555
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.9818 - mae: 8.9818
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13.4341 - mae: 13.4341
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.5528 - mae: 12.5528
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7929 - mae: 7.7929
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 12.5797 - mae: 12.5797
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.3087 - mae: 11.3087
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.5086 - mae: 9.5086
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.6944 - mae: 9.6944
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.9931 - mae: 11.9931
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.3206 - mae: 10.3206
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.7264 - mae: 9.7264
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.6477 - mae: 8.6477
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8172 - mae: 7.8172
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 11.2300 - mae: 11.2300
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 14.1422 - mae: 14.1422
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.2849 - mae: 19.2849
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.5144 - mae: 10.5144
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.3739 - mae: 9.3739
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.7525 - mae: 10.7525
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 11.3745 - mae: 11.3745
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.7136 - mae: 7.7136
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.4610 - mae: 8.4610
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.1366 - mae: 9.1366
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.8946 - mae: 21.8946
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.1164 - mae: 9.1164
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.3695 - mae: 10.3695
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.5023 - mae: 7.5023
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.7876 - mae: 10.7876
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.3716 - mae: 10.3716
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 16.0326 - mae: 16.0326
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.4039 - mae: 9.4039
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 11.2923 - mae: 11.2923
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.7584 - mae: 9.7584
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.7202 - mae: 9.7202
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.2663 - mae: 17.2663
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.9335 - mae: 8.9335
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.9114 - mae: 10.9114
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11.6502 - mae: 11.6502
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.4033 - mae: 10.4033
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 12.9868 - mae: 12.9868
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 15.6344 - mae: 15.6344
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.9099 - mae: 9.9099
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.2959 - mae: 9.2959
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.4927 - mae: 8.4927
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11.8126 - mae: 11.8126
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.7756 - mae: 9.7756
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.4052 - mae: 9.4052
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.6176 - mae: 8.6176
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 13.8158 - mae: 13.8158
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.4175 - mae: 8.4175
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 12.1701 - mae: 12.1701
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.5015 - mae: 9.5015
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.7529 - mae: 7.7529
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.3616 - mae: 9.3616
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.4500 - mae: 8.4500
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.7344 - mae: 9.7344
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 12.4796 - mae: 12.4796
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.9355 - mae: 10.9355
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.9388 - mae: 10.9388
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 12.0079 - mae: 12.0079
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.8462 - mae: 6.8462
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 12.9838 - mae: 12.9838
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 13.7845 - mae: 13.7845
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.7100 - mae: 6.7100
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.7524 - mae: 6.7524
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.5398 - mae: 6.5398
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 14.4624 - mae: 14.4624
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 12.3729 - mae: 12.3729
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.3789 - mae: 9.3789
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.2289 - mae: 9.2289
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.6676 - mae: 7.6676
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.5475 - mae: 13.5475
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.5366 - mae: 7.5366
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.1632 - mae: 8.1632

# %% [markdown]
# ### Visualizing the model

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4 (20.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
X[0],y[0]
# Out:
# (<tf.Tensor: shape=(), dtype=int32, numpy=-100>,
#  <tf.Tensor: shape=(), dtype=int32, numpy=-90>)

# %%
# Let's create a model which builds automatically by defining the input_shape argument in the first layer
tf.random.set_seed(42)

# 1. Create a model (same as above)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(10, input_shape=[1], name="input_layer"),
  tf.keras.layers.Dense(1, name="output_layer")
], name="model_1")

# 2. Compile the model (same as above)
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# %%
model.summary()
# Out:
# Model: "model_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (Dense)             │ (None, 10)             │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * Total params - total number of parameters in the model.
# * Trainable parameters - these are the parameters (patterns) the model can update as it trains.
# * Non-trainable params - these parameters aren't updated during training (this is typical when you bring in already learn patterns or parameters from other models during **transfer learning**).
#
# 📖 **Resource:** For a more in-depth overview of the trainable parameters within a layer, check out [MIT's introduction to deep learning video](https://youtu.be/njKP3FqW3Sk).
#
# 🛠 **Exercise:** Try playing around with the number of hidden units in the dense layer, see how that effects the number of parameters (total and trainable) by calling `model.summary()`.

# %%
# Set seed for reproducibility
tf.random.set_seed(42)

# 🔧 List of hidden unit values to test
hidden_units_list = [5, 10, 50, 100]

for units in hidden_units_list:
    print("\n" + "="*40)
    print(f"Model with {units} hidden units")
    print("="*40)

    # Create model
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(units, input_shape=[1], name="input_layer"),
        tf.keras.layers.Dense(1, name="output_layer")
    ])

    # Compile model
    model.compile(
        loss=tf.keras.losses.mae,
        optimizer=tf.keras.optimizers.SGD(),
        metrics=["mae"]
    )

    # Show summary
    model.summary()
# Out:
# ========================================
# Model with 5 hidden units
# ========================================
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (Dense)             │ (None, 5)              │            10 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16 (64.00 B)
#  Trainable params: 16 (64.00 B)
#  Non-trainable params: 0 (0.00 B)
# ========================================
# Model with 10 hidden units
# ========================================
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (Dense)             │ (None, 10)             │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)
# ========================================
# Model with 50 hidden units
# ========================================
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (Dense)             │ (None, 50)             │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151 (604.00 B)
#  Trainable params: 151 (604.00 B)
#  Non-trainable params: 0 (0.00 B)
# ========================================
# Model with 100 hidden units
# ========================================
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (Dense)             │ (None, 100)            │           200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 301 (1.18 KB)
#  Trainable params: 301 (1.18 KB)
#  Non-trainable params: 0 (0.00 B)
